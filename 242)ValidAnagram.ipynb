# %% [markdown]
# # 242 - Valid Anagram
#
# Example 1:
#
# > Input: s = "anagram", t = "nagaram"
#
# > Output: true
#
# Example 2:
#
# > Input: s = "rat", t = "car"
#
# > Output: false

# %%
def isAnagram(s, t):
    return sorted(s) == sorted(t)
# Out:
# True
